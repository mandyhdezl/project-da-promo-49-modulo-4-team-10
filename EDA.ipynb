# %% [markdown]
# Exploracion de 2 datasets:
# 1. Climate Change Impact on Agriculture
# 2. Sugar Consumption

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## EDA 🧼

# %%
df = pd.read_csv("climate_change_impact_on_agriculture_2024.csv")
()
# Out:
# ()

# %%
df.sample(20)
# Out:
#       Year    Country                      Region   Crop_Type  \
# 7155  1993      China                        East      Cotton
# 2975  2014     Brazil                       North      Coffee
# 9750  2013     Russia                     Central      Fruits
# 1603  1992     France               Ile-de-France        Corn
# 6843  1995  Australia           Western Australia  Vegetables
# 2435  1991      India                 Maharashtra      Coffee
# 6963  2014  Argentina                   Northeast        Rice
# 3856  1999        USA                        West      Cotton
# 9929  2013        USA                   Northeast      Cotton
# 8518  1997     France                   Grand Est    Soybeans
# 5033  2014     Russia                Northwestern      Coffee
# 6181  1998  Australia                  Queensland      Coffee
# 9692  2016     Russia                    Siberian  Vegetables
# 7754  1993  Australia             New South Wales      Coffee
# 6340  2019     France  Provence-Alpes-Cote d’Azur      Barley
# 9522  1993        USA                        West    Soybeans
# 6922  2019  Argentina                   Northeast        Corn
# 9397  2015      China                       North        Rice
# 6784  1992  Australia           Western Australia       Wheat
# 6502  2024  Australia           Western Australia      Cotton
#
#       Average_Temperature_C  Total_Precipitation_mm  CO2_Emissions_MT  \
# 7155                  28.62                 2199.04              4.64
# 2975                  -3.78                 1056.81             20.95
# 9750                  12.26                 1552.88             19.65
# 1603                   5.33                  417.15             28.52
# 6843                  30.99                 2982.60             10.02
# 2435                   2.91                 2060.12             15.07
# 6963                  -2.40                 2068.94             29.23
# 3856                   3.77                 2463.60             15.59
# 9929                  12.75                 2567.57              3.21
# 8518                  32.29                 1664.52             13.41
# 5033                  15.12                 2665.75              8.19
# 6181                  -4.14                  361.45             26.86
# 9692                  16.07                 1457.56             20.96
# 7754                  -3.65                 2971.02             27.94
# 6340                  16.73                  699.35              9.26
# 9522                  16.05                 1022.87             16.90
# 6922                  12.29                 1416.46             15.94
# 9397                  13.32                  737.04              6.33
# 6784                  28.88                 1945.67             11.84
# 6502                  -3.31                 1560.50              6.98
#
#       Crop_Yield_MT_per_HA  Extreme_Weather_Events  Irrigation_Access_%  \
# 7155                 3.260                      10                73.05
# 2975                 1.809                       4                37.88
# 9750                 2.196                       1                75.33
# 1603                 0.630                       1                66.63
# 6843                 1.470                       6                65.36
# 2435                 1.503                       2                87.10
# 6963                 2.682                       3                87.93
# 3856                 1.980                       6                21.15
# 9929                 2.300                       5                71.78
# 8518                 3.460                       9                59.53
# 5033                 4.040                       5                65.94
# 6181                 1.476                       3                36.54
# 9692                 2.034                       7                96.49
# 7754                 1.674                       8                15.45
# 6340                 4.750                       4                16.97
# 9522                 2.997                       3                64.67
# 6922                 3.528                       0                79.60
# 9397                 2.940                       1                12.07
# 6784                 0.980                      10                94.04
# 6502                 1.450                       2                69.08
#
#       Pesticide_Use_KG_per_HA  Fertilizer_Use_KG_per_HA  Soil_Health_Index  \
# 7155                    16.21                     31.55              38.25
# 2975                    31.62                     53.97              60.24
# 9750                    35.25                     30.01              89.14
# 1603                     2.52                      3.28              83.43
# 6843                    45.88                     34.36              89.53
# 2435                     6.97                     38.14              87.96
# 6963                    36.85                     97.06              38.07
# 3856                    32.98                     56.12              77.53
# 9929                    20.16                      2.17              31.74
# 8518                     9.51                      9.43              92.02
# 5033                    44.24                     18.96              95.47
# 6181                    40.71                     80.12              41.53
# 9692                     7.47                     95.84              34.96
# 7754                    31.45                     71.40              62.65
# 6340                    17.36                     90.61              61.60
# 9522                     2.03                      7.91              55.75
# 6922                     3.94                     61.67              99.77
# 9397                     3.05                     11.74              30.63
# 6784                    33.48                     60.60              86.36
# 6502                    10.04                     94.86              40.99
#
#         Adaptation_Strategies  Economic_Impact_Million_USD
# 7155         Water Management                      1600.13
# 2975          Organic Farming                       197.30
# 9750         Water Management                      1057.35
# 1603         Water Management                       134.80
# 6843         Water Management                       382.93
# 2435  Drought-resistant Crops                       495.34
# 6963         Water Management                       275.15
# 3856            Crop Rotation                       289.74
# 9929          Organic Farming                      1100.84
# 8518            Crop Rotation                       357.86
# 5033            Crop Rotation                      1225.86
# 6181            No Adaptation                       690.98
# 9692            No Adaptation                       470.34
# 7754          Organic Farming                       270.88
# 6340            No Adaptation                      1444.39
# 9522         Water Management                       543.50
# 6922  Drought-resistant Crops                       986.25
# 9397         Water Management                       967.83
# 6784            Crop Rotation                       135.96
# 6502  Drought-resistant Crops                       574.52

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
#  12  Soil_Health_Index            10000 non-null  float64
#  13  Adaptation_Strategies        10000 non-null  object
#  14  Economic_Impact_Million_USD  10000 non-null  float64
# dtypes: float64(9), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Year                           0.0
# Country                        0.0
# Region                         0.0
# Crop_Type                      0.0
# Average_Temperature_C          0.0
# Total_Precipitation_mm         0.0
# CO2_Emissions_MT               0.0
# Crop_Yield_MT_per_HA           0.0
# Extreme_Weather_Events         0.0
# Irrigation_Access_%            0.0
# Pesticide_Use_KG_per_HA        0.0
# Fertilizer_Use_KG_per_HA       0.0
# Soil_Health_Index              0.0
# Adaptation_Strategies          0.0
# Economic_Impact_Million_USD    0.0
# dtype: float64

# %%
df["Crop_Type"].value_counts()
# Out:
# Crop_Type
# Wheat         1047
# Cotton        1044
# Vegetables    1036
# Corn          1022
# Rice          1022
# Sugarcane      995
# Fruits         979
# Soybeans       958
# Barley         952
# Coffee         945
# Name: count, dtype: int64

# %%
df_sugar = pd.read_csv("sugar_consumption_dataset.csv")
df_sugar.sample(10)
# Out:
#         Country  Year Country_Code      Continent                   Region  \
# 7929   9.980157e+06   7.821898e+06                 3.867708      0.0
# 1261   9.771856e+06   6.899396e+06                 3.618048      0.0
# 591    3.916934e+06   2.026551e+06                 4.248500      0.0
# 7026   8.878333e+06   8.243808e+06                 0.580586      0.0
#
#       Gov_Subsidies  Education_Campaign  Urbanization_Rate  \
# 8941              0                 0.0          55.407899
# 4453              1                 0.0          85.829479
# 2848              1                 1.0          48.876167
# 2981              1                 1.0          71.620233
# 9558              1                 0.0          13.093263
# 8717              1                 0.0          54.550721
# 7929              0                 0.0          15.449687
# 1261              0                 1.0          21.518597
# 591               0                 0.0          72.685104
# 7026              0                 1.0          46.773034
#
#       Climate_Conditions  Sugarcane_Production_Yield
# 8941                   4                   49.420116
# 4453                   1                   43.051020
# 2848                   3                   33.490267
# 2981                   2                   84.655032
# 9558                   4                   81.428374
# 8717                   2                   89.495218
# 7929                   5                   45.748435
# 1261                   1                   67.464573
# 591                    1                   37.667023
# 7026                   3                   42.521456

# %%
df_sugar.isna().sum()/df_sugar.shape[0]*100
# Out:
# Country                         0.00
# Year                            0.00
# Country_Code                    0.00
# Continent                       0.00
# Region                          0.00
# Population                      0.00
# GDP_Per_Capita                  0.00
# Per_Capita_Sugar_Consumption    0.00
# Total_Sugar_Consumption         0.00
# Sugar_From_Sugarcane            0.00
# Sugar_From_Beet                 0.00
# Sugar_From_HFCS                 0.00
# Sugar_From_Other                0.00
# Processed_Food_Consumption      0.00
# Avg_Daily_Sugar_Intake          0.00
# Diabetes_Prevalence             0.00
# Obesity_Rate                    0.00
# Sugar_Imports                   0.00
# Sugar_Exports                   0.00
# Avg_Retail_Price_Per_Kg         0.00
# Gov_Tax                         5.31
# Gov_Subsidies                   0.00
# Education_Campaign              5.20
# Urbanization_Rate               0.00
# Climate_Conditions              0.00
# Sugarcane_Production_Yield      0.00
# dtype: float64

# %%
df_sugar.shape
# Out:
# (10000, 26)

# %% [markdown]
# - primer analisis:ver que paises tienen mayo produccion de caña de azucar
# - segundo analisis: unir dts para ver si coinciden los paises que tienen mayor produccion con los que consumen mas

# %%
df_sugarcane_cc = df[df['Crop_Type'] == 'Sugarcane']
df_sugarcane_cc
# Out:
#       Year    Country             Region  Crop_Type  Average_Temperature_C  \
# 4     1998      India         Tamil Nadu  Sugarcane                   2.19
# 10    2006    Nigeria         South East  Sugarcane                  -3.57
# 36    2015     Brazil              North  Sugarcane                  14.69
# 40    2020  Australia  Western Australia  Sugarcane                  17.77
# 50    2002      China              South  Sugarcane                   8.88
# ...    ...        ...                ...        ...                    ...
# 9916  2020     Brazil          Northeast  Sugarcane                   4.07
# 9982  2016        USA          Northeast  Sugarcane                  24.58
# 9983  2017        USA               West  Sugarcane                   7.35
# 9987  1996      China               East  Sugarcane                  16.46
# 9989  1994      China              North  Sugarcane                  -2.71
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 4                    1627.48             11.81                 1.080
# 10                   1402.97              5.49                 2.670
# 36                    804.11             23.52                 4.248
# 40                   1743.11             13.69                 1.690
# 50                    947.14             20.78                 2.241
# ...                      ...               ...                   ...
# 9916                 1688.35             14.38                 1.610
# 9982                 1067.86             15.60                 2.709
# 9983                 1107.90             21.69                 2.097
# 9987                 2686.87             21.21                 2.538
# 9989                  513.01             12.93                 0.780
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 4                          9                95.75                    44.35
# 10                        10                19.17                     4.38
# 36                         1                75.67                     1.73
# 40                         2                23.95                    39.15
# 50                         2                96.90                    41.57
# ...                      ...                  ...                      ...
# 9916                       1                26.01                    37.66
# 9982                       8                53.82                    31.12
# 9983                      10                69.90                     9.35
# 9987                       5                99.12                    36.39
# 9989                      10                71.76                    43.41
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 4                        88.08              49.61         Crop Rotation
# 10                       12.02              44.12      Water Management
# 36                       78.02              49.80         No Adaptation
# 40                       67.61              42.34      Water Management
# 50                       56.67              54.44         Crop Rotation
# ...                        ...                ...                   ...
# 9916                     73.95              37.12         Crop Rotation
# 9982                     75.01              46.00         Crop Rotation
# 9983                     51.99              36.50         Crop Rotation
# 9987                      5.82              96.34      Water Management
# 9989                     19.96              87.33      Water Management
#
#       Economic_Impact_Million_USD
# 4                          401.72
# 10                        1100.44
# 36                        1581.37
# 40                         440.49
# 50                         600.91
# ...                           ...
# 9916                       752.58
# 9982                      1291.31
# 9983                       592.90
# 9987                      1099.85
# 9989                       284.34
#
# [995 rows x 15 columns]

# %%
# Unir los DataFrames por las columnas 'year', 'country', 'region'
df_merged = pd.merge(df_sugarcane_cc, df_sugar, on=['Year', 'Country'], how='left')
df_merged.shape
# Out:
# (8915, 39)

# %%
df_merged.sample(20)
# Out:
#       Year    Country         Region_x  Crop_Type  Average_Temperature_C  \
# 1117  2002      India       Tamil Nadu  Sugarcane                  22.90
# 8323  2019      China            South  Sugarcane                  -0.86
# 6386  2000      China             East  Sugarcane                   9.72
# 7810  2022        USA          Midwest  Sugarcane                   1.13
# 8286  2001        USA          Midwest  Sugarcane                   3.23
# 1561  2004     France    Ile-de-France  Sugarcane                  11.90
# 527   2010     France        Grand Est  Sugarcane                  31.14
# 8402  2001      India      Maharashtra  Sugarcane                  30.71
# 8436  1993  Argentina        Patagonia  Sugarcane                  13.13
# 8600  1991     Brazil        Southeast  Sugarcane                   9.13
# 5057  1990        USA        Northeast  Sugarcane                  33.91
# 6547  2002        USA        Northeast  Sugarcane                   1.35
# 6791  2023      India      Maharashtra  Sugarcane                  14.27
# 8728  2017      China            North  Sugarcane                  34.63
# 2759  2002      India           Punjab  Sugarcane                   9.70
# 8154  2021     Russia          Central  Sugarcane                  15.87
# 4092  2010     Brazil            South  Sugarcane                  -0.71
# 5274  2020        USA            South  Sugarcane                  14.17
# 2584  1990  Australia  New South Wales  Sugarcane                  26.65
# 4876  2017      China            South  Sugarcane                  -2.55
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 1117                 2565.01             19.79                 3.096
# 8323                 1535.87             14.43                 2.060
# 6386                 2571.63             25.87                 1.962
# 7810                 2695.88             12.28                 1.700
# 8286                 2111.43             23.46                 1.035
# 1561                  656.69             18.52                 2.700
# 527                  1373.86             11.04                 2.890
# 8402                 2606.49             15.65                 1.494
# 8436                  553.40             29.95                 1.773
# 8600                 2110.90             12.01                 0.700
# 5057                 1208.28             26.33                 1.629
# 6547                 2365.74             16.04                 2.367
# 6791                 2954.33              2.39                 1.870
# 8728                 2225.61             10.30                 3.430
# 2759                  931.16              1.72                 1.050
# 8154                 2979.85             11.99                 4.290
# 4092                  249.56              5.99                 1.080
# 5274                  272.87             20.75                 2.718
# 2584                 1047.96             23.75                 3.177
# 4876                 2732.86              2.18                 2.540
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 1117                       9                77.32                    17.76
# 8323                       5                39.28                     5.40
# 6386                       3                97.04                    30.28
# 7810                       9                96.51                     0.91
# 8286                       9                90.11                    28.74
# 1561                       9                26.95                    38.37
# 527                        7                40.97                    18.76
# 8402                       1                22.53                     0.63
# 8436                       1                70.00                    28.92
# 8600                       3                19.30                    16.89
# 5057                       1                75.41                    27.86
# 6547                       3                79.68                    33.58
# 6791                       5                15.04                    38.84
# 8728                       1                71.21                    42.07
# 2759                       2                36.09                    19.16
# 8154                       9                47.17                    47.75
# 4092                       9                44.36                    47.64
# 5274                       2                31.15                    21.87
# 2584                       2                81.07                    11.45
# 4876                       3                50.88                    42.49
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 1117                     23.81              61.45          Organic Farming
# 8323                     10.84              65.71  Drought-resistant Crops
# 6386                      9.02              73.54  Drought-resistant Crops
# 7810                     76.57              94.66          Organic Farming
# 8286                     22.40              38.78            No Adaptation
# 1561                     30.78              95.32         Water Management
# 527                      83.82              38.37  Drought-resistant Crops
# 8402                     85.03              60.26          Organic Farming
# 8436                     81.65              80.75            No Adaptation
# 8600                     29.95              74.84            No Adaptation
# 5057                     21.57              47.50            No Adaptation
# 6547                      0.29              53.41         Water Management
# 6791                     56.65              81.96  Drought-resistant Crops
# 8728                     46.14              42.88         Water Management
# 2759                     71.71              50.14         Water Management
# 8154                     70.72              33.88          Organic Farming
# 4092                     75.62              51.66  Drought-resistant Crops
# 5274                     84.75              95.27            Crop Rotation
# 2584                     29.88              85.93  Drought-resistant Crops
# 4876                     56.06              47.07            No Adaptation
#
#       Economic_Impact_Million_USD Country_Code      Continent  \
# 1117                      1350.02          IND           Asia
# 8323                       414.18          CHN           Asia
# 6386                       923.57          CHN           Asia
# 7810                       678.06          USA  North America
# 8286                       188.66          USA  North America
# 1561                       701.18          FRA         Europe
# 527                        815.29          FRA         Europe
# 8402                       151.58          IND           Asia
# 8436                       769.59          NaN            NaN
# 8600                       131.62          BRA  South America
# 5057                       274.79          USA  North America
# 6547                       625.79          USA  North America
# 6791                       763.24          IND           Asia
# 8728                      1558.24          CHN           Asia
# 2759                       413.42          IND           Asia
# 8154                      1187.51          RUS         Europe
# 4092                       397.40          BRA  South America
# 5274                       292.14          USA  North America
# 2584                      1517.92          AUS        Oceania
# 4876                       867.92          CHN           Asia
#
#                      Region_y    Population  GDP_Per_Capita  \
# 1117               South Asia  1.243567e+08    47025.668802
# 8402          80.072948                 2.0                   95.147623
# 8436                NaN                 NaN                         NaN
# 8600          72.657736                 5.0                   44.731124
# 5057          47.578624                 1.0                   61.005106
# 6547          19.993254                 4.0                   99.194541
# 6791          13.143382                 4.0                   92.777018
# 8728          73.044847                 2.0                   87.179237
# 2759          23.066975                 1.0                   88.924474
# 8154          37.375728                 5.0                   58.259967
# 4092          63.564334                 2.0                   39.721772
# 5274          33.448628                 5.0                   79.832217
# 2584          36.268213                 4.0                   54.141812
# 4876          66.719389                 2.0                   55.379101

# %%
df_merged.isnull().sum()
# Out:
# Year                              0
# Country                           0
# Region_x                          0
# Crop_Type                         0
# Average_Temperature_C             0
# Total_Precipitation_mm            0
# CO2_Emissions_MT                  0
# Crop_Yield_MT_per_HA              0
# Extreme_Weather_Events            0
# Irrigation_Access_%               0
# Pesticide_Use_KG_per_HA           0
# Fertilizer_Use_KG_per_HA          0
# Soil_Health_Index                 0
# Adaptation_Strategies             0
# Economic_Impact_Million_USD       0
# Country_Code                    329
# Continent                       329
# Region_y                        329
# Population                      329
# GDP_Per_Capita                  329
# Per_Capita_Sugar_Consumption    329
# Total_Sugar_Consumption         329
# Sugar_From_Sugarcane            329
# Sugar_From_Beet                 329
# Sugar_From_HFCS                 329
# Sugar_From_Other                329
# Processed_Food_Consumption      329
# Avg_Daily_Sugar_Intake          329
# Diabetes_Prevalence             329
# Obesity_Rate                    329
# Sugar_Imports                   329
# Sugar_Exports                   329
# Avg_Retail_Price_Per_Kg         329
# Gov_Tax                         787
# Gov_Subsidies                   329
# Education_Campaign              785
# Urbanization_Rate               329
# Climate_Conditions              329
# Sugarcane_Production_Yield      329
# dtype: int64

# %%
df_merged["Country"].unique()
# Out:
# array(['India', 'Nigeria', 'Brazil', 'Australia', 'China', 'Canada',
#        'France', 'Russia', 'USA', 'Argentina'], dtype=object)

# %%
df_sugar["Country"].unique()
# Out:
# array(['France', 'Australia', 'Germany', 'South Africa', 'India',
#        'Mexico', 'Russia', 'Brazil', 'USA', 'China', 'Indonesia', 'Japan'],
#       dtype=object)

# %%
df_sugarcane_cc["Country"].value_counts()
# Out:
# Country
# Nigeria      122
# India        109
# China        109
# Argentina    106
# Australia    100
# USA           99
# Russia        97
# Brazil        91
# Canada        82
# France        80
# Name: count, dtype: int64

# %%
df_sugarcane_cc.head(2)
# Out:
#     Year  Country      Region  Crop_Type  Average_Temperature_C  \
# 4   1998    India  Tamil Nadu  Sugarcane                   2.19
# 10  2006  Nigeria  South East  Sugarcane                  -3.57
#
#     Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 4                  1627.48             11.81                  1.08
# 10                 1402.97              5.49                  2.67
#
#     Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 4                        9                95.75                    44.35
# 10                      10                19.17                     4.38
#
#     Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 4                      88.08              49.61         Crop Rotation
# 10                     12.02              44.12      Water Management
#
#     Economic_Impact_Million_USD
# 4                        401.72
# 10                      1100.44

# %%
top6_paises_money = df_sugarcane_cc.groupby('Country')['Economic_Impact_Million_USD'].mean().sort_values(ascending=False).head(6)

top6_paises_money
# Out:
# Country
# India        776.299450
# Nigeria      723.735984
# Argentina    714.307925
# Canada       713.334878
# Brazil       705.843407
# Russia       699.899794
# Name: Economic_Impact_Million_USD, dtype: float64

# %%
top5_paises_ha = df_sugarcane_cc.groupby('Country')['Crop_Yield_MT_per_HA'].mean().sort_values(ascending=False).head()
top5_paises_ha
# Out:
# Country
# Russia       2.370278
# Nigeria      2.354607
# India        2.351376
# Argentina    2.337981
# Australia    2.337000
# Name: Crop_Yield_MT_per_HA, dtype: float64

# %%
df_sugar["Country"].value_counts()
# Out:
# Country
# Australia       917
# Indonesia       877
# France          861
# Japan           846
# Germany         832
# India           829
# Mexico          820
# Russia          817
# South Africa    816
# USA             800
# China           797
# Brazil          788
# Name: count, dtype: int64

# %%
"""La media de consumo de azucar (de todos los grupos) por país"""

top3_paises_consumo = df_sugar.groupby('Country')['Total_Sugar_Consumption'].mean().sort_values(ascending=False).head(3)
top3_paises_consumo
# Out:
# Country
# Japan      5.866933e+06
# Germany    5.865261e+06
# India      5.785490e+06
# Name: Total_Sugar_Consumption, dtype: float64

# %%
df_sugarcane_cc['Year'].sort_values()
# Out:
# 868     1990
# 9507    1990
# 982     1990
# 4665    1990
# 4957    1990
#         ...
# 5151    2024
# 1395    2024
# 1080    2024
# 3559    2024
# 3120    2024
# Name: Year, Length: 995, dtype: int64

# %%
for c in df_sugar.select_dtypes(exclude='O').columns:
    top3_paises_consumo = df_sugar.groupby('Country')[c].mean().sort_values(ascending=False).head(3)
    print(f"Top 3 países con mayor media de consumo en la columna '{c}':")
    print(top3_paises_consumo)
    print("-" * 50)
# Out:
# Top 3 países con mayor media de consumo en la columna 'Year':
# Country
# Brazil       1992.520305
# Russia       1992.328029
# Indonesia    1991.854048
# Name: Year, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Population':
# Country
# Russia       1.552386e+08
# Australia    1.530646e+08
# Germany      1.521795e+08
# Name: Population, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'GDP_Per_Capita':
# Country
# Germany      26338.948163
# Mexico       25830.228324
# Australia    25710.909999
# Name: GDP_Per_Capita, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Per_Capita_Sugar_Consumption':
# Country
# Japan      39.088050
# Germany    38.411954
# India      38.248380
# Name: Per_Capita_Sugar_Consumption, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Total_Sugar_Consumption':
# Country
# Japan      5.866933e+06
# Germany    5.865261e+06
# India      5.785490e+06
# Name: Total_Sugar_Consumption, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_From_Sugarcane':
# Country
# Japan     70.565413
# China     70.544778
# Russia    70.526585
# Name: Sugar_From_Sugarcane, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_From_Beet':
# Country
# Indonesia    23.143155
# Russia       22.923919
# Australia    22.707842
# Name: Sugar_From_Beet, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_From_HFCS':
# Country
# Brazil       30.716818
# Australia    30.571417
# Germany      30.313622
# Name: Sugar_From_HFCS, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_From_Other':
# Country
# China    -21.462146
# Brazil   -21.690729
# France   -21.806541
# Name: Sugar_From_Other, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Processed_Food_Consumption':
# Country
# France       165.003416
# Germany      157.212922
# Indonesia    157.162482
# Name: Processed_Food_Consumption, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Avg_Daily_Sugar_Intake':
# Country
# Japan      107.101258
# Germany    105.248753
# India      104.800560
# Name: Avg_Daily_Sugar_Intake, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Diabetes_Prevalence':
# Country
# Japan     9.721268
# Brazil    9.476181
# Russia    9.416215
# Name: Diabetes_Prevalence, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Obesity_Rate':
# Country
# France    23.230721
# Mexico    22.893333
# Brazil    22.436955
# Name: Obesity_Rate, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_Imports':
# Country
# China    5.215054e+06
# India    5.133998e+06
# USA      5.104384e+06
# Name: Sugar_Imports, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugar_Exports':
# Country
# Mexico       5.277195e+06
# USA          5.237477e+06
# Australia    5.197851e+06
# Name: Sugar_Exports, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Avg_Retail_Price_Per_Kg':
# Country
# USA             2.811030
# South Africa    2.785396
# Indonesia       2.772702
# Name: Avg_Retail_Price_Per_Kg, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Gov_Tax':
# Country
# Germany         0.181242
# India           0.173691
# South Africa    0.164721
# Name: Gov_Tax, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Gov_Subsidies':
# Country
# India     0.317250
# Brazil    0.315990
# China     0.313676
# Name: Gov_Subsidies, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Education_Campaign':
# Country
# Japan        0.430000
# USA          0.428571
# Australia    0.420273
# Name: Education_Campaign, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Urbanization_Rate':
# Country
# India           51.019491
# Indonesia       50.841933
# South Africa    50.585332
# Name: Urbanization_Rate, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Climate_Conditions':
# Country
# South Africa    3.061275
# Russia          3.017136
# China           3.005019
# Name: Climate_Conditions, dtype: float64
# --------------------------------------------------
# Top 3 países con mayor media de consumo en la columna 'Sugarcane_Production_Yield':
# Country
# China           66.497459
# Russia          66.041918
# South Africa    65.752169
# Name: Sugarcane_Production_Yield, dtype: float64
# --------------------------------------------------

# %%
# Guardar csv filtrado de Sugarcane

df_sugarcane_cc.to_csv('climate_change_filt_Sugarcane.csv', index=False)

# %% [markdown]
# - df_sugarcane_cc: dataset de agricultura, produccion
# - df_sugar: dataset de consumo

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_sugar["Diabetes_Prevalence"], df_sugar["Obesity_Rate"], color='c', alpha=0.5)
plt.title("Relación entre la distancia de los vuelos y los puntos acumulados")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filtramos solo columnas numéricas
df_correlaciones = df_sugarcane_cc.select_dtypes(exclude='object').corr()

# Luego hacemos el heatmap como ya lo tienes
plt.figure(figsize=(15, 15))

mask = np.triu(np.ones_like(df_correlaciones, dtype=bool))

sns.heatmap(df_correlaciones,
            annot=True,
            fmt=".2f",
            cmap="mako",
            vmax=1,
            vmin=-1,
            mask=mask)
plt.title("Mapa de correlación de columnas numéricas")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_sugarcane_cc["Crop_Yield_MT_per_HA"], df_sugarcane_cc["Economic_Impact_Million_USD"], color='c', alpha=0.5)


plt.grid(True)
plt.tight_layout()
plt.show()

# %%
correlacion = df_sugarcane_cc["Crop_Yield_MT_per_HA"].corr(df_sugarcane_cc["Economic_Impact_Million_USD"])
correlacion
# Out:
# np.float64(0.7338041571116132)

# %%
# Filtramos solo columnas numéricas
df_correlaciones2 = df_sugar.select_dtypes(exclude='object').corr()

# Luego hacemos el heatmap como ya lo tienes
plt.figure(figsize=(15, 15))

mask = np.triu(np.ones_like(df_correlaciones2, dtype=bool))

sns.heatmap(df_correlaciones2,
            annot=True,
            fmt=".2f",
            cmap="mako",
            vmax=1,
            vmin=-1,
            mask=mask)
plt.title("Mapa de correlación de columnas numéricas")
plt.show()

# %%
df_sugar.sample(20)
# Out:
#            Country  Year Country_Code      Continent                   Region  \
# 4810  South Africa  1964          ZAF         Africa       Sub-Saharan Africa
# 801          India  1977          IND           Asia               South Asia
# 2011        Mexico  1987          MEX  North America          Central America
# 4886     Australia  2021          AUS        Oceania  Australia & New Zealand
# 4464       Germany  2015          DEU         Europe           Western Europe
# 3846     Indonesia  1987          IDN           Asia           Southeast Asia
# 2366        Brazil  1999          BRA  South America            South America
# 8626        Russia  1962          RUS         Europe           Eastern Europe
# 3499  South Africa  1975          ZAF         Africa       Sub-Saharan Africa
# 4814         India  1964          IND           Asia               South Asia
# 6203     Indonesia  1979          IDN           Asia           Southeast Asia
# 1864         Japan  1994          JPN           Asia                East Asia
# 2550       Germany  1985          DEU         Europe           Western Europe
# 5245     Australia  1963          AUS        Oceania  Australia & New Zealand
# 1710        Brazil  1964          BRA  South America            South America
# 6359     Australia  2022          AUS        Oceania  Australia & New Zealand
# 5443         China  2012          CHN           Asia                East Asia
# 7588     Indonesia  2011          IDN           Asia           Southeast Asia
# 3366         Japan  1970          JPN           Asia                East Asia
# 1805        Mexico  1982          MEX  North America          Central America
#
#         Population  GDP_Per_Capita  Per_Capita_Sugar_Consumption  \
# 4810  1.522240e+07    42815.309442                     63.204465
# 801   7.457602e+07    36641.125312                     16.805717
# 2011  5.650253e+07    36205.557461                     11.545768
# 4886  3.729568e+07    16185.084218                     13.945646
# 4464  2.965420e+08    35037.295144                     49.763173
# 4814               46.627711            14.899029      5.310685
# 6203               86.483791             9.514401     23.467480
# 1864              133.468683             8.439656     10.344714
# 2550               63.371807            11.207253     39.449968
# 5245              120.443558            10.721519     24.233537
# 1710              162.740484             4.257821     19.370529
# 6359               29.971933             6.725564     38.779359
# 5443               96.898112             7.695030     25.783640
# 7588              124.746659             4.212113     39.508021
# 3366              158.914760             9.941000      7.063229
# 1805               15.660376             7.797259     18.298207
#
#       Sugar_Imports  Sugar_Exports  Avg_Retail_Price_Per_Kg  Gov_Tax  \
# 4810   6.112619e+06   4.939227e+06                 4.966612      0.0
# 801    9.660477e+06   4.288881e+06                 1.228508      0.0
# 2011   8.814153e+06   2.591851e+06                 0.626739      1.0
# 4886   6.609050e+06   1.377216e+06                 2.387793      0.0
# 4464   9.368183e+06   2.643638e+06                 0.826206      0.0
# 3846   6.883053e+06   1.733021e+06                 2.154660      1.0
# 2366   1.613079e+06   1.721796e+05                 4.855198      0.0
# 8626   3.947936e+06   2.981287e+06                 1.905899      0.0
# 3499   9.195840e+06   1.738332e+06                 4.882216      0.0
# 4814   5.449990e+06   2.347194e+06                 4.118374      0.0
# 6203   3.307999e+04   8.511769e+06                 3.912993      0.0
# 1864   7.727566e+05   2.263220e+06                 1.604351      0.0
# 2550   2.904714e+06   8.752770e+06                 2.635717      0.0
# 5245   7.705743e+06   7.943697e+06                 3.207955      NaN
# 1710   6.139096e+06   9.049350e+06                 4.684063      0.0
# 6359   2.187322e+06   9.246462e+06                 4.374649      0.0
# 5443   5.509240e+06   4.479246e+06                 1.642437      0.0
# 7588   1.617396e+06   7.441201e+06                 0.765130      0.0
# 3366   7.369511e+06   8.923625e+06                 4.689754      0.0
# 1805   7.006714e+06   9.706787e+06                 3.491647      0.0
#
#       Gov_Subsidies  Education_Campaign  Urbanization_Rate  \
# 4810              0                 0.0          13.377944
# 801               1                 1.0          43.345698
# 2011              0                 0.0          85.588454
# 4886              0                 0.0          73.990628
# 4464              0                 0.0          70.518070
# 3846              1                 0.0          78.312771
# 2366              0                 1.0          75.589659
# 8626              1                 0.0          44.177264
# 3499              0                 0.0          44.028443
# 4814              1                 0.0          11.795221
# 6203              0                 0.0          70.580676
# 1864              0                 NaN          26.402659
# 2550              0                 1.0          35.422795
# 5245              0                 1.0          81.749296
# 1710              1                 1.0          40.447217
# 6359              1                 1.0          70.680349
# 5443              0                 1.0          84.977928
# 7588              0                 0.0          36.178548
# 3366              0                 0.0          12.081223
# 1805              1                 1.0          15.337530
#
#       Climate_Conditions  Sugarcane_Production_Yield
# 4810                   1                   66.327721
# 801                    5                   64.336628
# 2011                   2                   45.166709
# 4886                   4                   45.084130
# 4464                   3                   76.904412
# 3846                   3                   44.554370
# 2366                   1                   34.194390
# 8626                   1                   96.714091
# 3499                   2                   81.529014
# 4814                   1                   65.893194
# 6203                   5                   64.855752
# 1864                   2                   32.034519
# 2550                   3                   60.769465
# 5245                   2                   71.459679
# 1710                   3                   84.980939
# 6359                   1                   43.833220
# 5443                   1                   86.575355
# 7588                   2                   38.785446
# 3366                   5                   91.455214
# 1805                   4                   38.180719
